# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as urlo

def movie_image(movie):
    movie = movie.replace(' ','+')
    movie = movie + '+movie+poster'
    browser = webdriver.Chrome(executable_path='chromedriver')
    url = 'https://www.google.com/search?q='+movie+'&source=lnms&tbm=isch&sa=X&ved=0ahUKEwiYhd6bq6zhAhVFLY8KHWEKCk8Q_AUIDigB&biw=1440&bih=730'
    browser.get(url)
    time.sleep(1)
    html = browser.page_source
    soup1 = soup(html)
    for i in soup1.findAll('div',{'data-ri':'0'}):
        x = (i.a['href'])
        break
    x = 'https://www.google.com'+x
    url = x
    browser.get(url)
    time.sleep(0.5)
    html = browser.page_source
    soup1 = soup(html)
    x=[]
    i = soup1.findAll('img',{'class':'irc_mi'})
    browser.quit()
    return (i[1]['src'])
    



# movies.drop(['genres','vote_average','genre_binary','cast_binary','director_binary','words_bin','director'],axis=1,inplace=True)

# %%
import pandas as pd

movies = pd.read_csv('movies_with_url2.csv' , encoding='cp1252')

# %%
movies.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'budget', 'genres', 'homepage', 'id',
#        'keywords', 'original_language', 'original_title', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title_x', 'vote_average', 'vote_count', 'movie_id',
#        'title_y', 'cast', 'director', 'genres_bin', 'cast_bin', 'director_bin',
#        'words_bin', 'url'],
#       dtype='object')

# %%
movies = movies.iloc[:,1:]

# %%
type(movies.iloc[4644,29])
# Out:
# str

# %%
for i in range(len(movies)):
    print(str(i)+"/"+str(len(movies)))
    if movies.iloc[i,29] == 'null':
        try:
            movies.iloc[i , 29 ] = movie_image(movies.iloc[i , 7])
        except:
            pass
# Out:
# 0/4645
# 1/4645
# 2/4645
# 3/4645
# 4/4645
# 5/4645
# 6/4645
# 7/4645
# 8/4645
# 9/4645
# 10/4645
# 11/4645
# 12/4645
# 13/4645
# 14/4645
# 15/4645
# 16/4645
# 17/4645
# 18/4645
# 19/4645
# 20/4645
# 21/4645
# C:\Users\sssha\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\sssha\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 22/4645
# 23/4645
# 24/4645
# 25/4645
# 26/4645
# 27/4645
# 28/4645
# 29/4645
# 30/4645
# 31/4645
# 32/4645
# 33/4645
# 34/4645
# 35/4645
# 36/4645
# ...

# %%
movies.to_csv("movies_with_url2.csv" , header =['Unnamed: 0', 'budget', 'genres', 'homepage', 'id', 'keywords',
       'original_language', 'original_title', 'overview', 'popularity',
       'production_companies', 'production_countries', 'release_date',
       'revenue', 'runtime', 'spoken_languages', 'status', 'tagline',
       'title_x', 'vote_average', 'vote_count', 'movie_id', 'title_y', 'cast',
       'director', 'genres_bin', 'cast_bin', 'director_bin', 'words_bin',
       'url'] )

# %%
movies.columns
# Out:
# Index(['Unnamed: 0', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title_x', 'vote_average', 'vote_count', 'movie_id', 'title_y', 'cast',
#        'director', 'genres_bin', 'cast_bin', 'director_bin', 'words_bin',
#        'url'],
#       dtype='object')

# %%
movies.to_csv("movies_with_url.csv" , header =['Unnamed: 0', 'budget', 'genres', 'homepage', 'id', 'keywords',
       'original_language', 'original_title', 'overview', 'popularity',
       'production_companies', 'production_countries', 'release_date',
       'revenue', 'runtime', 'spoken_languages', 'status', 'tagline',
       'title_x', 'vote_average', 'vote_count', 'movie_id', 'title_y', 'cast',
       'director', 'genres_bin', 'cast_bin', 'director_bin', 'words_bin',
       'url'] )
